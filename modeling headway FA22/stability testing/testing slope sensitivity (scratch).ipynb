# %%
# for 10 km case

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
S_atr_high = [0.03556704, 0.01439749, 0.00884956, 0.00269038, 0.00140822,
       0.00079611, 0.00047654, 0.00029881, 0.00019509]
S_atr_low = [0.03679287, 0.01521229, 0.00951728, 0.00385872, 0.00263019,
       0.00192292, 0.0014755 , 0.001173  , 0.00095808]
S_no_atr = [0.0367835 , 0.01520734, 0.00951389, 0.00385759, 0.00262951,
       0.00192249, 0.00147522, 0.00117281, 0.00095796]
S_corrected_ql = [0.03677981, 0.01520362, 0.00951011, 0.003854  , 0.00262621,
       0.00191945, 0.00147241, 0.00117019, 0.00095551]
S_tinygamma = [0.03678349, 0.01520733, 0.00951388, 0.00385759, 0.00262951,
       0.00192249, 0.00147522, 0.00117281, 0.00095796]

# %%
plt.plot(S_atr_high, label = 'with high attrition')
plt.plot(S_atr_low, label = 'with low attrition (persistant sediment)')
plt.plot(S_no_atr, label = 'without attrition')
plt.plot(S_corrected_ql, label = 'with standard attrition, corrected ql contribution')
plt.plot(S_tinygamma, label = 'gamma needed for ideal slope, in theory')
plt.legend()

# %%
ql_gamma100_standard = [0.00000000e+00, 3.33333361e-08, 1.66666680e-08, 1.11111120e-08,
       8.33333402e-09, 6.66666722e-09, 5.55555602e-09, 4.76190476e-09,
       4.16666701e-09, 3.70370401e-09]
ql_gamma30_standard = [0.00000000e+00, 1.00000008e-08, 5.00000041e-09, 3.33333361e-09,
       2.50000021e-09, 2.00000017e-09, 1.66666680e-09, 1.42857143e-09,
       1.25000010e-09, 1.11111120e-09]
ql_gamma30_high_atr = [0.00000000e+00, 9.99983334e-09, 4.99995833e-09, 3.33331481e-09,
       2.49990625e-09, 1.99994000e-09, 1.66662500e-09, 1.42854082e-09,
       1.24997656e-09, 1.11109259e-09]
ql_gamma100_high_atr = [0.00000000e+00, 3.33333111e-08, 1.66666611e-08, 1.11111086e-08,
       8.33331944e-09, 6.66665778e-09, 5.55554938e-09, 4.76190023e-09,
       4.16666319e-09, 3.70370096e-09]

# %%
#plt.plot(ql_gamma100_standard, label = '100 % coarse contribution, standard atrrition')
plt.plot(ql_gamma30_standard, label = '30% coarse contribution, standard attrition')
plt.plot(ql_gamma30_high_atr, label = '30% coarse, high attrition')
#plt.plot(ql_gamma100_high_atr, label = '100% coarse, high attrition')
plt.legend()
