Q_data_005 = [Q_005[0], Q_005[9], Q_005[19], Q_005[29], Q_005[39], Q_005[49], Q_005[59], Q_005[69], Q_005[79], 
              Q_005[89], Q_005[98]]

# %%
b_data_r1 = 65.98635811798061
depth_data_r1 = 1.0926432137479976
Q_data_r1 = 1.03714286e+02

# %%
# make arrays
b_array_def = np.array(b_data_def)
depth_array_def = np.array(depth_data_def)
Q_array_def = np.array(Q_data_def)

b_array_U = np.array(b_data_U)
depth_array_U = np.array(depth_data_U)
Q_array_U = np.array(Q_data_U)

b_array_02 = np.array(b_data_02)
depth_array_02 = np.array(depth_data_02)
Q_array_02 = np.array(Q_data_02)

b_array_005 = np.array(b_data_005)
depth_array_005 = np.array(depth_data_005)
Q_array_005 = np.array(Q_data_005)

# %%
global_data = pd.read_excel('comparison with phillips_complete_sans_DA.xlsx')

# %%
short_data = pd.read_excel('short_comp.xlsx')

# %%
global_data
# Out:
#        tau_*bf    Slope  D50 (m)  Width (m)  Depth (m)  Discharge (m3/s)
# 0     0.037195  0.00510   0.0831       12.1       1.00              21.2
# 1     0.046596  0.00740   0.0385        5.3       0.40               1.8
# 2     0.044470  0.00500   0.0477       12.6       0.70               9.7
# 3     0.035690  0.00530   0.0450       13.6       0.50               4.7
# 4     0.051337  0.00560   0.0595       12.7       0.90              10.6
# ...        ...      ...      ...        ...        ...               ...
# 1570  0.019993  0.00370   0.0830       17.0       0.74              24.0
# 1571  0.034205  0.00280   0.0640       20.0       1.29              40.0
# 1572  0.004885  0.00066   0.1040       18.0       1.27              45.0
# 1573  0.030413  0.00069   0.0220       27.0       1.60              66.0
# 1574  0.011503  0.00062   0.0490       23.0       1.50              68.0
#
# [1575 rows x 6 columns]

# %%
short_data['Dimensionless discharge'] = short_data['Discharge (m3/s)']/(np.sqrt(2.65 * 9.81 * (short_data['D50 (m)']**5)))
short_data['Dimensionless width'] = short_data['Width (m)'] / short_data['D50 (m)']
short_data['Dimensionless depth'] = short_data['Depth (m)'] / short_data['D50 (m)']

# %%
global_data['Dimensionless width'] = global_data['Width (m)'] / global_data['D50 (m)']
global_data['Dimensionless discharge'] = global_data['Discharge (m3/s)']/(np.sqrt(2.65 * 9.81 * (global_data['D50 (m)']**5)))
# global_data['Dimensionless discharge'] = global_data['Discharge (m3/s)']/(np.sqrt(9.81 * (global_data['D50 (m)']**5)))
global_data['Dimensionless depth'] = global_data['Depth (m)'] / global_data['D50 (m)']

# %%
my_Q_data_015_def = np.concatenate((Q_array_def), axis = None)
my_width_data_015_def = np.concatenate((b_array_def), axis = None)
my_depth_data_015_def = np.concatenate((depth_array_def), axis = None)

my_Q_data_015_U = np.concatenate((Q_array_U), axis = None)
my_width_data_015_U = np.concatenate((b_array_U), axis = None)
my_depth_data_015_U = np.concatenate((depth_array_U), axis = None)

my_Q_data_02 = np.concatenate((Q_array_02), axis = None)
my_width_data_02 = np.concatenate((b_array_02), axis = None)
my_depth_data_02 = np.concatenate((depth_array_02), axis = None)

my_Q_data_005 = np.concatenate((Q_array_005), axis = None)
my_width_data_005 = np.concatenate((b_array_005), axis = None)
my_depth_data_005 = np.concatenate((depth_array_005), axis = None)

# %%
my_Q_nondim_015_def = my_Q_data_015_def / (np.sqrt(2.65 * 9.81 * (0.015)**5))
my_width_nondim_015_def = np.array(my_width_data_015_def) / 0.015
my_depth_nondim_015_def = my_depth_data_015_def / 0.015

my_Q_nondim_015_U = my_Q_data_015_U / (np.sqrt(2.65 * 9.81 * (0.015)**5))
my_width_nondim_015_U = np.array(my_width_data_015_U) / 0.015
my_depth_nondim_015_U = my_depth_data_015_U / 0.015

my_Q_nondim_02 = my_Q_data_02 / (np.sqrt(2.65 * 9.81 * (0.02)**5))
my_width_nondim_02 = np.array(my_width_data_02) / 0.02
my_depth_nondim_02 = my_depth_data_02 / 0.02

my_Q_nondim_005 = my_Q_data_005 / (np.sqrt(2.65 * 9.81 * (0.005)**5))
my_width_nondim_005 = np.array(my_width_data_005) / 0.005
my_depth_nondim_005 = my_depth_data_005 / 0.005

my_Q_nondim_r1 = Q_data_r1 / (np.sqrt(2.65 * 9.81 * (0.015)**5))
my_width_nondim_r1 = b_data_r1 / 0.015
my_depth_nondim_r1 = depth_data_r1 / 0.015

# %%
len(my_Q_nondim_02)
# Out:
# 11

# %%
plt.rcParams['figure.dpi'] = 300
# plt.rcParams['savefig.dpi'] = 300

plt.figure(figsize = (8, 4))

plt.scatter(global_data['Dimensionless discharge'], global_data['Dimensionless width'], marker = 'o', color = 'silver', alpha = 0.1, label = 'Global alluvial rivers')
plt.plot(0, 0, color = 'darkgreen', label = 'Threshold theory')
# plt.scatter(my_Q_nondim_015, my_width_nondim_015, marker = 'x', color = 'dodgerblue', label = 'Model prediction')
# plt.scatter(my_Q_nondim_02, my_width_nondim_02, marker = 'x', color = 'dodgerblue')
# plt.scatter(my_Q_nondim_005, my_width_nondim_005, marker = 'x', color = 'dodgerblue')
# plt.scatter(short_data['Dimensionless discharge'], short_data['Dimensionless width'], marker = 'x', color = 'goldenrod') #, label = 'Likely bedrock-incising')

plt.xlim(1e1, 1e15)
plt.ylim(1e1, 1e8)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Dimensionless discharge ($Q/\sqrt{(g D_{50}^5)}$)', fontsize = 16)
plt.ylabel('Dimensionless width ($W/D_{50}$)', fontsize = 16)
plt.legend(loc = 'upper left', fontsize = 14)

plt.savefig('AGU_width_discharge_global.png', transparent = True)
plt.show()

# %%
plt.rcParams['figure.dpi'] = 300
# plt.rcParams['savefig.dpi'] = 300

plt.figure(figsize = (8, 4))

plt.scatter(global_data['Dimensionless discharge'], global_data['Dimensionless depth'], marker = 'o', color = 'silver', alpha = 0.1, label = 'Global rivers')
plt.plot(0, 0.0001, label = 'Threshold theory', color = 'darkgreen')
# plt.scatter(my_Q_nondim_015, my_depth_nondim_015, marker = 'x', color = 'dodgerblue', label = 'Model prediction')
# plt.scatter(my_Q_nondim_02, my_depth_nondim_02, marker = 'x', color = 'dodgerblue')
# plt.scatter(my_Q_nondim_005, my_depth_nondim_005, marker = 'x', color = 'dodgerblue')
# plt.scatter(short_data['Dimensionless discharge'], short_data['Dimensionless depth'], marker = 'x', color = 'goldenrod', label = 'Likely bedrock-incising')

plt.xlim(1e1, 1e15)
plt.ylim(1e-1, 1e6)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Dimensionless discharge ($Q/\sqrt{(g D_{50}^5)}$)', fontsize = 16)
plt.ylabel('Dimensionless depth ($d/D_{50}$)', fontsize = 16)
plt.legend(fontsize = 14)

plt.savefig('AGU_depth_discharge_global.png', transparent = True)
plt.show()

# %%
plt.rcParams['figure.dpi'] = 300
# plt.rcParams['savefig.dpi'] = 300

plt.figure(figsize = (8, 4))

plt.scatter(global_data['Dimensionless discharge'], global_data['Dimensionless width'], marker = 'o', color = 'silver', alpha = 0.1, label = 'Global alluvial rivers')
plt.plot(0, 0, color = 'darkgreen', label = 'Threshold theory')
plt.scatter(my_Q_nondim_015_def[-1], my_width_nondim_015_def[-1], marker = 'o', color = 'dodgerblue', label = 'Model predictions')
plt.scatter(my_Q_nondim_015_U[-1], my_width_nondim_015_U[-1], marker = 'o', color = 'dodgerblue')
plt.scatter(my_Q_nondim_02[-1], my_width_nondim_02[-1], marker = 'o', color = 'dodgerblue')
plt.scatter(my_Q_nondim_005[-1], my_width_nondim_005[-1], marker = 'o', color = 'dodgerblue')
plt.scatter(my_Q_nondim_r1, my_width_nondim_r1, marker = 'o', color = 'dodgerblue')
# plt.scatter(short_data['Dimensionless discharge'], short_data['Dimensionless width'], marker = 'x', color = 'goldenrod') #, label = 'Likely bedrock-incising')

plt.xlim(1e1, 1e15)
plt.ylim(1e1, 1e8)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Dimensionless discharge ($Q/\sqrt{(g D_{50}^5)}$)', fontsize = 16)
plt.ylabel('Dimensionless width ($W/D_{50}$)', fontsize = 16)
plt.legend(loc = 'upper left', fontsize = 14)

plt.savefig('AGU_width_discharge_model.png', transparent = True)
plt.show()

# %%
plt.rcParams['figure.dpi'] = 300
# plt.rcParams['savefig.dpi'] = 300

plt.figure(figsize = (8, 4))

plt.scatter(global_data['Dimensionless discharge'], global_data['Dimensionless depth'], marker = 'o', color = 'silver', alpha = 0.1, label = 'Global alluvial rivers')
plt.plot(0, 0, color = 'darkgreen', label = 'Threshold theory')
plt.scatter(my_Q_nondim_015_def[-1], my_depth_nondim_015_def[-1], marker = 'o', color = 'dodgerblue', label = 'Model predictions')
plt.scatter(my_Q_nondim_015_U[-1], my_depth_nondim_015_U[-1], marker = 'o', color = 'dodgerblue')
plt.scatter(my_Q_nondim_02[-1], my_depth_nondim_02[-1], marker = 'o', color = 'dodgerblue')
plt.scatter(my_Q_nondim_005[-1], my_depth_nondim_005[-1], marker = 'o', color = 'dodgerblue')
plt.scatter(my_Q_nondim_r1, my_depth_nondim_r1, marker = 'o', color = 'dodgerblue')
# plt.scatter(short_data['Dimensionless discharge'], short_data['Dimensionless width'], marker = 'x', color = 'goldenrod') #, label = 'Likely bedrock-incising')

plt.xlim(1e1, 1e15)
plt.ylim(1e-1, 1e6)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Dimensionless discharge ($Q/\sqrt{(g D_{50}^5)}$)', fontsize = 16)
plt.ylabel('Dimensionless depth ($d/D_{50}$)', fontsize = 16)
plt.legend(loc = 'upper left', fontsize = 14)

plt.savefig('AGU_depth_discharge_model.png', transparent = True)
plt.show()

# %%
short_data
# Out:
#     ID                   Citation  \
# 0   28               Andrews 1984
# 1   44               Andrews 1984
# 2   36               Andrews 1984
# 3   35               Andrews 1984
# 4  665  Elliott and Cartier, 1986
#
#                                            Site_Name  Drainage area (km^2)  \
# 0    Fraser River at Upper STA, near Winter Park, CO              27.20000
# 1                 South Fork Williams Fork near Leal              70.50000
# 2  Crystal River above Avalanche Creek, near Reds...             433.00000
# 3                           Chalk Creek near Nathrop             251.00000
# 4                  PICEANCE CREEK AT WHITE RIVER, CO            1688.67348
#
#     tau_*bf   Slope  D50 (m)  Width (m)  Depth (m)  Discharge (m3/s)  \
# 0  0.072371  0.0140  0.03400       6.98       0.29              2.69
# 1  0.053549  0.0150  0.07300       9.00       0.43              8.40
# 2  0.030130  0.0058  0.09800      34.00       0.84             49.00
# ...

# %%
plt.rcParams['figure.dpi'] = 300
# plt.rcParams['savefig.dpi'] = 300

plt.figure(figsize = (8, 4))

plt.scatter(global_data['Dimensionless discharge'], global_data['Dimensionless width'], marker = 'o', color = 'silver', alpha = 0.1, label = 'Global alluvial rivers')
plt.plot(0, 0, color = 'darkgreen', label = 'Threshold theory')
plt.scatter(my_Q_nondim_015_def[-1], my_width_nondim_015_def[-1], marker = 'o', color = 'dodgerblue', label = 'Model predictions')
plt.scatter(my_Q_nondim_015_U[-1], my_width_nondim_015_U[-1], marker = 'o', color = 'dodgerblue')
plt.scatter(my_Q_nondim_02[-1], my_width_nondim_02[-1], marker = 'o', color = 'dodgerblue')
plt.scatter(my_Q_nondim_005[-1], my_width_nondim_005[-1], marker = 'o', color = 'dodgerblue')
plt.scatter(my_Q_nondim_r1, my_width_nondim_r1, marker = 'o', color = 'dodgerblue')
plt.scatter(short_data['Dimensionless discharge'][0], short_data['Dimensionless width'][0], marker = 'o', color = 'goldenrod', label = 'Potentially bedrock-incising')
plt.scatter(short_data['Dimensionless discharge'][3], short_data['Dimensionless width'][3], marker = 'o', color = 'goldenrod') #, label = 'Likely bedrock-incising')

plt.xlim(1e1, 1e15)
plt.ylim(1e1, 1e8)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Dimensionless discharge ($Q/\sqrt{(g D_{50}^5)}$)', fontsize = 16)
plt.ylabel('Dimensionless width ($W/D_{50}$)', fontsize = 16)
plt.legend(loc = 'upper left', fontsize = 14)

plt.savefig('AGU_width_discharge_colorado_model.png', transparent = True)
plt.show()
