# %%
# this notebook will contain code to make a slope-area figure

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# define domain area
dx = 500
x = np.arange(0, 50000, dx)
area = (1./3.) * x**2

# %%
# import slopes
slope_default = np.genfromtxt('slope_default.csv', delimiter=',')
slope_1 = np.genfromtxt('slope_exp_1.csv', delimiter=',')
slope_2 = np.genfromtxt('slope_exp_2.csv', delimiter=',')
slope_3 = np.genfromtxt('slope_exp_3.csv', delimiter=',')
slope_4 = np.genfromtxt('slope_exp_4.csv', delimiter=',')
slope_5 = np.genfromtxt('slope_exp_5.csv', delimiter=',')
slope_6 = np.genfromtxt('slope_exp_6.csv', delimiter=',')
slope_7 = np.genfromtxt('slope_exp_7.csv', delimiter=',')
slope_8 = np.genfromtxt('slope_exp_8.csv', delimiter=',')
slope_9 = np.genfromtxt('slope_exp_9.csv', delimiter=',')
slope_10 = np.genfromtxt('slope_exp_10.csv', delimiter=',')
slope_11 = np.genfromtxt('slope_exp_11.csv', delimiter=',')
slope_12 = np.genfromtxt('slope_exp_12.csv', delimiter=',')
slope_13 = np.genfromtxt('slope_exp_13.csv', delimiter=',')
slope_14 = np.genfromtxt('slope_exp_14.csv', delimiter=',')
slope_15 = np.genfromtxt('slope_exp_15.csv', delimiter=',')
slope_16 = np.genfromtxt('slope_exp_16.csv', delimiter=',')

# %%
# repeatable workflow for figure-making
#--------------------------------------

# DEFAULT
m_default, b_default = np.polyfit(np.log(area[1:]), np.log(slope_default), 1)
slope_fit_default = np.exp((m_default * np.log(area[1:])) + b_default)

upper_bound_total_m_default = m_default + 0.05
lower_bound_total_m_default = m_default - 0.05

upper_bound_total_slope_fit_default = np.exp((upper_bound_total_m_default * np.log(area[1:])) + b_default)
lower_bound_total_slope_fit_default = np.exp((lower_bound_total_m_default * np.log(area[1:])) + b_default)
#---------------------------------------------------------------------------------

# EXPERIMENT 1
m_1, b_1 = np.polyfit(np.log(area[1:]), np.log(slope_1), 1)
slope_fit_1 = np.exp((m_1 * np.log(area[1:])) + b_1)

upper_bound_total_m_1 = m_1 + 0.05
lower_bound_total_m_1 = m_1 - 0.05

upper_bound_total_slope_fit_1 = np.exp((upper_bound_total_m_1 * np.log(area[1:])) + b_1)
lower_bound_total_slope_fit_1 = np.exp((lower_bound_total_m_1 * np.log(area[1:])) + b_1)
#---------------------------------------------------------------------------------

# EXPERIMENT 2
m_2, b_2 = np.polyfit(np.log(area[1:]), np.log(slope_2), 1)
slope_fit_2 = np.exp((m_2 * np.log(area[1:])) + b_2)

upper_bound_total_m_2 = m_2 + 0.05
lower_bound_total_m_2 = m_2 - 0.05

upper_bound_total_slope_fit_2 = np.exp((upper_bound_total_m_2 * np.log(area[1:])) + b_2)
lower_bound_total_slope_fit_2 = np.exp((lower_bound_total_m_2 * np.log(area[1:])) + b_2)
#---------------------------------------------------------------------------------

# EXPERIMENT 3
m_3, b_3 = np.polyfit(np.log(area[1:]), np.log(slope_3), 1)
slope_fit_3 = np.exp((m_3 * np.log(area[1:])) + b_3)

upper_bound_total_m_3 = m_3 + 0.05
lower_bound_total_m_3 = m_3 - 0.05

upper_bound_total_slope_fit_3 = np.exp((upper_bound_total_m_3 * np.log(area[1:])) + b_3)
lower_bound_total_slope_fit_3 = np.exp((lower_bound_total_m_3 * np.log(area[1:])) + b_3)
#---------------------------------------------------------------------------------

# EXPERIMENT 4
m_4, b_4 = np.polyfit(np.log(area[1:]), np.log(slope_4), 1)
slope_fit_4 = np.exp((m_4 * np.log(area[1:])) + b_4)

upper_bound_total_m_4 = m_4 + 0.05
lower_bound_total_m_4 = m_4 - 0.05

upper_bound_total_slope_fit_4 = np.exp((upper_bound_total_m_4 * np.log(area[1:])) + b_4)
lower_bound_total_slope_fit_4 = np.exp((lower_bound_total_m_4 * np.log(area[1:])) + b_4)
#---------------------------------------------------------------------------------

# EXPERIMENT 5
m_5, b_5 = np.polyfit(np.log(area[1:]), np.log(slope_5), 1)
slope_fit_5 = np.exp((m_5 * np.log(area[1:])) + b_5)

upper_bound_total_m_5 = m_5 + 0.05
lower_bound_total_m_5 = m_5 - 0.05

upper_bound_total_slope_fit_5 = np.exp((upper_bound_total_m_5 * np.log(area[1:])) + b_5)
lower_bound_total_slope_fit_5 = np.exp((lower_bound_total_m_5 * np.log(area[1:])) + b_5)
#---------------------------------------------------------------------------------

# EXPERIMENT 6
m_6, b_6 = np.polyfit(np.log(area[1:]), np.log(slope_6), 1)
slope_fit_6 = np.exp((m_6 * np.log(area[1:])) + b_6)

upper_bound_total_m_6 = m_6 + 0.05
lower_bound_total_m_6 = m_6 - 0.05

upper_bound_total_slope_fit_6 = np.exp((upper_bound_total_m_6 * np.log(area[1:])) + b_6)
lower_bound_total_slope_fit_6 = np.exp((lower_bound_total_m_6 * np.log(area[1:])) + b_6)
#---------------------------------------------------------------------------------

# EXPERIMENT 7
m_7, b_7 = np.polyfit(np.log(area[1:]), np.log(slope_7), 1)
slope_fit_7 = np.exp((m_7 * np.log(area[1:])) + b_7)

upper_bound_total_m_7 = m_7 + 0.05
lower_bound_total_m_7 = m_7 - 0.05

upper_bound_total_slope_fit_7 = np.exp((upper_bound_total_m_7 * np.log(area[1:])) + b_7)
lower_bound_total_slope_fit_7 = np.exp((lower_bound_total_m_7 * np.log(area[1:])) + b_7)
#---------------------------------------------------------------------------------

# EXPERIMENT 8
m_8, b_8 = np.polyfit(np.log(area[1:]), np.log(slope_8), 1)
slope_fit_8 = np.exp((m_8 * np.log(area[1:])) + b_8)

upper_bound_total_m_8 = m_8 + 0.05
lower_bound_total_m_8 = m_8 - 0.05

upper_bound_total_slope_fit_8 = np.exp((upper_bound_total_m_8 * np.log(area[1:])) + b_8)
lower_bound_total_slope_fit_8 = np.exp((lower_bound_total_m_8 * np.log(area[1:])) + b_8)
#---------------------------------------------------------------------------------

# EXPERIMENT 9
m_9, b_9 = np.polyfit(np.log(area[1:]), np.log(slope_9), 1)
slope_fit_9 = np.exp((m_9 * np.log(area[1:])) + b_9)

upper_bound_total_m_9 = m_9 + 0.05
lower_bound_total_m_9 = m_9 - 0.05

upper_bound_total_slope_fit_9 = np.exp((upper_bound_total_m_9 * np.log(area[1:])) + b_9)
lower_bound_total_slope_fit_9 = np.exp((lower_bound_total_m_9 * np.log(area[1:])) + b_9)
#---------------------------------------------------------------------------------

# EXPERIMENT 10
m_10, b_10 = np.polyfit(np.log(area[1:]), np.log(slope_10), 1)
slope_fit_10 = np.exp((m_10 * np.log(area[1:])) + b_10)

upper_bound_total_m_10 = m_10 + 0.05
lower_bound_total_m_10 = m_10 - 0.05

upper_bound_total_slope_fit_10 = np.exp((upper_bound_total_m_10 * np.log(area[1:])) + b_10)
lower_bound_total_slope_fit_10 = np.exp((lower_bound_total_m_10 * np.log(area[1:])) + b_10)
#---------------------------------------------------------------------------------

# EXPERIMENT 11
m_11, b_11 = np.polyfit(np.log(area[1:]), np.log(slope_11), 1)
slope_fit_11 = np.exp((m_11 * np.log(area[1:])) + b_11)

upper_bound_total_m_11 = m_11 + 0.05
lower_bound_total_m_11 = m_11 - 0.05

upper_bound_total_slope_fit_11 = np.exp((upper_bound_total_m_11 * np.log(area[1:])) + b_11)
lower_bound_total_slope_fit_11 = np.exp((lower_bound_total_m_11 * np.log(area[1:])) + b_11)
#---------------------------------------------------------------------------------

# EXPERIMENT 12
m_12, b_12 = np.polyfit(np.log(area[1:]), np.log(slope_12), 1)
slope_fit_12 = np.exp((m_12 * np.log(area[1:])) + b_12)

upper_bound_total_m_12 = m_12 + 0.05
lower_bound_total_m_12 = m_12 - 0.05

upper_bound_total_slope_fit_12 = np.exp((upper_bound_total_m_12 * np.log(area[1:])) + b_12)
lower_bound_total_slope_fit_12 = np.exp((lower_bound_total_m_12 * np.log(area[1:])) + b_12)
#---------------------------------------------------------------------------------

# EXPERIMENT 13
m_13, b_13 = np.polyfit(np.log(area[1:]), np.log(slope_13), 1)
slope_fit_13 = np.exp((m_13 * np.log(area[1:])) + b_13)

upper_bound_total_m_13 = m_13 + 0.05
lower_bound_total_m_13 = m_13 - 0.05

upper_bound_total_slope_fit_13 = np.exp((upper_bound_total_m_13 * np.log(area[1:])) + b_13)
lower_bound_total_slope_fit_13 = np.exp((lower_bound_total_m_13 * np.log(area[1:])) + b_13)
#---------------------------------------------------------------------------------

# EXPERIMENT 14
m_14, b_14 = np.polyfit(np.log(area[1:]), np.log(slope_14), 1)
slope_fit_14 = np.exp((m_14 * np.log(area[1:])) + b_14)

upper_bound_total_m_14 = m_14 + 0.05
lower_bound_total_m_14 = m_14 - 0.05

upper_bound_total_slope_fit_14 = np.exp((upper_bound_total_m_14 * np.log(area[1:])) + b_14)
lower_bound_total_slope_fit_14 = np.exp((lower_bound_total_m_14 * np.log(area[1:])) + b_14)
#---------------------------------------------------------------------------------

# EXPERIMENT 15
m_15, b_15 = np.polyfit(np.log(area[1:]), np.log(slope_15), 1)
slope_fit_15 = np.exp((m_15 * np.log(area[1:])) + b_15)

upper_bound_total_m_15 = m_15 + 0.05
lower_bound_total_m_15 = m_15 - 0.05

upper_bound_total_slope_fit_15 = np.exp((upper_bound_total_m_15 * np.log(area[1:])) + b_15)
lower_bound_total_slope_fit_15 = np.exp((lower_bound_total_m_15 * np.log(area[1:])) + b_15)
#---------------------------------------------------------------------------------

# EXPERIMENT 16
m_16, b_16 = np.polyfit(np.log(area[1:]), np.log(slope_16), 1)
slope_fit_16 = np.exp((m_16 * np.log(area[1:])) + b_16)

upper_bound_total_m_16 = m_16 + 0.05
lower_bound_total_m_16 = m_16 - 0.05

upper_bound_total_slope_fit_16 = np.exp((upper_bound_total_m_16 * np.log(area[1:])) + b_16)
lower_bound_total_slope_fit_16 = np.exp((lower_bound_total_m_16 * np.log(area[1:])) + b_16)
#---------------------------------------------------------------------------------

# %%
# now make a pretty figure
plt.rcParams['figure.dpi'] = 300
fig, axs = plt.subplots(2, 2, figsize = (14, 10))

fig.text(0.5, 0.05, 'log (Area, $m^2$)', ha='center', fontsize = 22)
fig.text(0.05, 0.5, 'log (Slope)', va='center', rotation='vertical', fontsize = 22)

axs[0, 0].grid(alpha = 0.2)
axs[0, 0].plot(area[1:], slope_1, label = '$K = 1 x 10 ^{-7}$', color = 'k', linestyle = '-')
axs[0, 0].plot(area[1:], slope_2, label = '$K = 3.2 x 10 ^{-7}$', color = 'k', linestyle = '--')
axs[0, 0].plot(area[1:], slope_default, label = '$K = 1 x 10 ^{-6}$', color = 'goldenrod', linewidth = 3)
axs[0, 0].plot(area[1:], slope_3, label = '$K = 3.2 x 10 ^{-6}$', color = 'k', linestyle = '-.')
axs[0, 0].plot(area[1:], slope_4, label = '$K = 1 x 10 ^{-5}$', color = 'k', linestyle = ':')
axs[0, 0].set_title('A', fontsize = 20, x=0.05,y=0.05)
axs[0, 0].tick_params(axis="x", labelsize=14) 
axs[0, 0].tick_params(axis="y", labelsize=14)
axs[0, 0].set_yscale('log')
axs[0, 0].set_xscale('log')
axs[0, 0].legend(fontsize = 14)

axs[0, 1].grid(alpha = 0.2)
axs[0, 1].plot(area[1:], slope_5, label = '$r = 1$', color = 'k', linestyle = '-')
axs[0, 1].plot(area[1:], slope_6, label = '$r = 2.5$', color = 'k', linestyle = '--')
axs[0, 1].plot(area[1:], slope_default, label = '$r = 5$', color = 'goldenrod', linewidth = 3)
axs[0, 1].plot(area[1:], slope_7, label = '$r = 7.5$', color = 'k', linestyle = '-.')
axs[0, 1].plot(area[1:], slope_8, label = '$r = 10$', color = 'k', linestyle = ':')
axs[0, 1].set_title('B', fontsize = 20, x=0.05,y=0.05)
axs[0, 1].tick_params(axis="x", labelsize=14) 
axs[0, 1].tick_params(axis="y", labelsize=14)
axs[0, 1].set_yscale('log')
axs[0, 1].set_xscale('log')
axs[0, 1].legend(fontsize = 14)

axs[1, 0].grid(alpha = 0.2)
axs[1, 0].plot(area[1:], slope_9, label = '$k_{Qs} = 0.021$', color = 'k', linestyle = '-')
axs[1, 0].plot(area[1:], slope_10, label = '$k_{Qs} = 0.031$', color = 'k', linestyle = '--')
axs[1, 0].plot(area[1:], slope_default, label = '$k_{Qs} = 0.041$', color = 'goldenrod', linewidth = 3)
axs[1, 0].plot(area[1:], slope_11, label = '$k_{Qs} = 0.051$', color = 'k', linestyle = '-.')
axs[1, 0].plot(area[1:], slope_12, label = '$k_{Qs} = 0.061$', color = 'k', linestyle = ':')
axs[1, 0].set_title('C', fontsize = 20, x=0.05,y=0.05)
axs[1, 0].tick_params(axis="x", labelsize=14) 
axs[1, 0].tick_params(axis="y", labelsize=14)
axs[1, 0].set_yscale('log')
axs[1, 0].set_xscale('log')
axs[1, 0].legend(fontsize = 14)

axs[1, 1].grid(alpha = 0.2)
axs[1, 1].plot(area[1:], slope_13, label = '$\gamma = 0.25$', color = 'k', linestyle = '-')
axs[1, 1].plot(area[1:], slope_14, label = '$\gamma = 0.375$', color = 'k', linestyle = '--')
axs[1, 1].plot(area[1:], slope_default, label = '$\gamma = 0.5$', color = 'goldenrod', linewidth = 3)
axs[1, 1].plot(area[1:], slope_15, label = '$\gamma = 0.625$', color = 'k', linestyle = '-.')
axs[1, 1].plot(area[1:], slope_16, label = '$\gamma = 0.75$', color = 'k', linestyle = ':')
axs[1, 1].set_title('D', fontsize = 20, x=0.05,y=0.05)
axs[1, 1].tick_params(axis="x", labelsize=14) 
axs[1, 1].tick_params(axis="y", labelsize=14)
axs[1, 1].set_yscale('log')
axs[1, 1].set_xscale('log')
axs[1, 1].legend(fontsize = 14)

plt.savefig('slope area fig.pdf', bbox_inches='tight')
plt.show()
