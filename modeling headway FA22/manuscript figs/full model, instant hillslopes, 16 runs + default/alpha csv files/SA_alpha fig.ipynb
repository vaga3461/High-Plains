# %%
# this notebook will contain a four-square plot for elevation data sensitivity analysis

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# import alpha csvs
default = np.genfromtxt('alpha_default.csv', delimiter=',')
exp_1 = np.genfromtxt('alpha_exp_1.csv', delimiter=',')
exp_2 = np.genfromtxt('alpha_exp_2.csv', delimiter=',')
exp_3 = np.genfromtxt('alpha_exp_3.csv', delimiter=',')
exp_3p = np.genfromtxt('alpha_exp_3p.csv', delimiter=',')
exp_4 = np.genfromtxt('alpha_exp_4.csv', delimiter=',')
exp_5 = np.genfromtxt('alpha_exp_5.csv', delimiter=',')
exp_6 = np.genfromtxt('alpha_exp_6.csv', delimiter=',')
exp_7 = np.genfromtxt('alpha_exp_7.csv', delimiter=',')
exp_8 = np.genfromtxt('alpha_exp_8.csv', delimiter=',')
exp_9 = np.genfromtxt('alpha_exp_9.csv', delimiter=',')
exp_10 = np.genfromtxt('alpha_exp_10.csv', delimiter=',')
exp_11 = np.genfromtxt('alpha_exp_11.csv', delimiter=',')
exp_12 = np.genfromtxt('alpha_exp_12.csv', delimiter=',')
exp_13 = np.genfromtxt('alpha_exp_13.csv', delimiter=',')
exp_14 = np.genfromtxt('alpha_exp_14.csv', delimiter=',')
exp_15 = np.genfromtxt('alpha_exp_15.csv', delimiter=',')
exp_16 = np.genfromtxt('alpha_exp_16.csv', delimiter=',')

# %%
# test to see if 3 and 3p are same
test = exp_3 - exp_3p
print(test)
# Out:
# [-0.04876996 -0.12663907 -0.23990715 -0.35038692 -0.43145    -0.48235165
#  -0.50982892 -0.52064976 -0.52048176 -0.51373407 -0.50353    -0.49188107
#  -0.47998273 -0.46849633 -0.45775749 -0.44791167 -0.43899692 -0.43099287
#  -0.42384919 -0.41750194 -0.41188278 -0.40692412 -0.40256174 -0.39873608
#  -0.39539269 -0.39248223 -0.38996027 -0.38778692 -0.38592644 -0.38434684
#  -0.38301948 -0.38191873 -0.38102162 -0.38030758 -0.37975813 -0.37935669
#  -0.37908833 -0.37893965 -0.37889853 -0.37895408 -0.37909644 -0.37931672
#  -0.37960686 -0.3799596  -0.38036834 -0.3808271  -0.38133047 -0.38187353
#  -0.38245182 -0.38306131 -0.38369832 -0.38435952 -0.38504188 -0.38574265
#  -0.38645933 -0.38718967 -0.38793161 -0.38868328 -0.38944299 -0.39020922
#  -0.39098057 -0.39175579 -0.39253375 -0.39331341 -0.39409386 -0.39487426
#  -0.39565386 -0.39643199 -0.39720803 -0.39798145 -0.39875177 -0.39951855
#  -0.4002814  -0.40104    -0.40179404 -0.40254325 -0.40328741 -0.40402632
# ...

# %%
plt.rcParams['figure.dpi'] = 300
fig, axs = plt.subplots(2, 2, figsize = (14, 10))

fig.text(0.5, 0.05, 'Distance (km)', ha='center', fontsize = 22)
fig.text(0.05, 0.5, '$Q_s / Q_c $' '  (''1 - ' r'$\alpha$'')', va='center', rotation='vertical', fontsize = 22)

axs[0, 0].grid(alpha = 0.2)
axs[0, 0].plot(1 - exp_1[:-1], label = '$K = 1 x 10 ^{-7}$', color = 'midnightblue', linestyle = '-')
axs[0, 0].plot(1 - exp_2[:-1], label = '$K = 3.2 x 10 ^{-7}$', color = 'midnightblue', linestyle = '--')
axs[0, 0].plot(1 - default[:-1], label = '$K = 1 x 10 ^{-6}$', color = 'goldenrod', linewidth = 3)
axs[0, 0].plot(1 - exp_3[:-1], label = '$K = 3.2 x 10 ^{-6}$', color = 'midnightblue', linestyle = '-.')
axs[0, 0].plot(1 - exp_4[:-1], label = '$K = 1 x 10 ^{-5}$', color = 'midnightblue', linestyle = ':')
axs[0, 0].set_title('A', fontsize = 20, x=0.05,y=0.85)
axs[0, 0].tick_params(axis="x", labelsize=14) 
axs[0, 0].tick_params(axis="y", labelsize=14)
axs[0, 0].set_ylim(0, 1)
axs[0, 0].legend(fontsize = 14)

axs[0, 1].grid(alpha = 0.2)
axs[0, 1].plot(1 - exp_5[:-1], label = '$r = 1$', color = 'midnightblue', linestyle = '-')
axs[0, 1].plot(1 - exp_6[:-1], label = '$r = 2.5$', color = 'midnightblue', linestyle = '--')
axs[0, 1].plot(1 - default[:-1], label = '$r = 5$', color = 'goldenrod', linewidth = 3)
axs[0, 1].plot(1 - exp_7[:-1], label = '$r = 7.5$', color = 'midnightblue', linestyle = '-.')
axs[0, 1].plot(1 - exp_8[:-1], label = '$r = 10$', color = 'midnightblue', linestyle = ':')
axs[0, 1].set_title('B', fontsize = 20, x=0.05,y=0.85)
axs[0, 1].tick_params(axis="x", labelsize=14) 
axs[0, 1].tick_params(axis="y", labelsize=14)
axs[0, 1].set_ylim(0, 1)
axs[0, 1].legend(fontsize = 14)

axs[1, 0].grid(alpha = 0.2)
axs[1, 0].plot(1 - exp_9[:-1], label = '$k_{Qs} = 0.021$', color = 'midnightblue', linestyle = '-')
axs[1, 0].plot(1 - exp_10[:-1], label = '$k_{Qs} = 0.031$', color = 'midnightblue', linestyle = '--')
axs[1, 0].plot(1 - default[:-1], label = '$k_{Qs} = 0.041$', color = 'goldenrod', linewidth = 3)
axs[1, 0].plot(1 - exp_11[:-1], label = '$k_{Qs} = 0.051$', color = 'midnightblue', linestyle = '-.')
axs[1, 0].plot(1 - exp_12[:-1], label = '$k_{Qs} = 0.061$', color = 'midnightblue', linestyle = ':')
axs[1, 0].set_title('C', fontsize = 20, x=0.05,y=0.85)
axs[1, 0].tick_params(axis="x", labelsize=14) 
axs[1, 0].tick_params(axis="y", labelsize=14)
axs[1, 0].set_ylim(0, 1)
axs[1, 0].legend(fontsize = 14)

axs[1, 1].grid(alpha = 0.2)
axs[1, 1].plot(1 - exp_13[:-1], label = '$\gamma = 0.25$', color = 'midnightblue', linestyle = '-')
axs[1, 1].plot(1 - exp_14[:-1], label = '$\gamma = 0.375$', color = 'midnightblue', linestyle = '--')
axs[1, 1].plot(1 - default[:-1], label = '$\gamma = 0.5$', color = 'goldenrod', linewidth = 3)
axs[1, 1].plot(1 - exp_15[:-1], label = '$\gamma = 0.625$', color = 'midnightblue', linestyle = '-.')
axs[1, 1].plot(1 - exp_16[:-1], label = '$\gamma = 0.75$', color = 'midnightblue', linestyle = ':')
axs[1, 1].set_title('D', fontsize = 20, x=0.05,y=0.85)
axs[1, 1].tick_params(axis="x", labelsize=14) 
axs[1, 1].tick_params(axis="y", labelsize=14)
axs[1, 1].set_ylim(0, 1)
axs[1, 1].legend(fontsize = 14)

plt.savefig('transport capacity 2.pdf', bbox_inches='tight')
plt.show()

# %%
dx = 500
x = np.arange(0, 50000, dx)

# %%
kxb_1 = 25
kxb_2 = 80
pxb = 1./5.

B_1 = kxb_1 * x**(pxb)
B_2 = kxb_2 * x**(pxb)

# %%
plt.plot(B_1)
plt.plot(B_2)

# %%
beta = 0.0005

prod_1 = beta * B_1
prod_2 = beta * B_2

# %%
plt.plot(prod_1)
plt.plot(prod_2)
