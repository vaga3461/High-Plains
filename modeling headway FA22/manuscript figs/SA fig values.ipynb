# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# reused vals

dx = 1000
x = np.arange(0, 100000, dx)
area = (1./3.) * x**2

# %%
# RUN 1 (K = 1e-8, beta & psi = 1e-4)

slope_1 = [2.45502642e-01, 7.45315725e-02, 3.61607982e-02, 2.16315213e-02,
       1.45651943e-02, 1.05799726e-02, 8.09953219e-03, 6.44279852e-03,
       5.27598426e-03, 4.41961774e-03, 3.77006074e-03, 3.26396632e-03,
       2.86077581e-03, 2.53349800e-03, 2.26357396e-03, 2.03788038e-03,
       1.84690981e-03, 1.68362684e-03, 1.54272725e-03, 1.42014521e-03,
       1.31271774e-03, 1.21795134e-03, 1.13385662e-03, 1.05882907e-03,
       9.91561739e-04, 9.30980440e-04, 8.76194946e-04, 8.26461859e-04,
       7.81156029e-04, 7.39748321e-04, 7.01788163e-04, 6.66889735e-04,
       6.34720930e-04, 6.04994486e-04, 5.77460790e-04, 5.51902018e-04,
       5.28127321e-04, 5.05968849e-04, 4.85278452e-04, 4.65924929e-04,
       4.47791716e-04, 4.30774941e-04, 4.14781774e-04, 3.99729033e-04,
       3.85541981e-04, 3.72153306e-04, 3.59502243e-04, 3.47533811e-04,
       3.36198154e-04, 3.25449976e-04, 3.15248036e-04, 3.05554721e-04,
       2.96335659e-04, 2.87559390e-04, 2.79197066e-04, 2.71222197e-04,
       2.63610416e-04, 2.56339279e-04, 2.49388080e-04, 2.42737695e-04,
       2.36370431e-04, 2.30269903e-04, 2.24420916e-04, 2.18809362e-04,
       2.13422126e-04, 2.08247004e-04, 2.03272626e-04, 1.98488388e-04,
       1.93884390e-04, 1.89451380e-04, 1.85180704e-04, 1.81064258e-04,
       1.77094447e-04, 1.73264148e-04, 1.69566672e-04, 1.65995736e-04,
       1.62545427e-04, 1.59210185e-04, 1.55984770e-04, 1.52864243e-04,
       1.49843944e-04, 1.46919477e-04, 1.44086686e-04, 1.41341643e-04,
       1.38680633e-04, 1.36100140e-04, 1.33596831e-04, 1.31167549e-04,
       1.28809300e-04, 1.26519243e-04, 1.24294679e-04, 1.22133044e-04,
       1.20031903e-04, 1.17988938e-04, 1.16001944e-04, 1.14068820e-04,
       1.12187567e-04, 1.10356278e-04, 1.08573135e-04]
#-----------------------------------------------------------------
# RUN 2 (K = 1e-7, beta & psi = 1e-4)

slope_2 = [3.39055919e-02, 1.33476674e-02, 8.01512382e-03, 5.68176030e-03,
       4.38457732e-03, 3.55916353e-03, 2.98688506e-03, 2.56606030e-03,
       2.24314098e-03, 1.98726677e-03, 1.77939352e-03, 1.60712113e-03,
       1.46201926e-03, 1.33814946e-03, 1.23120276e-03, 1.13797305e-03,
       1.05602294e-03, 9.83464574e-04, 9.18811761e-04, 8.60877638e-04,
       8.08702281e-04, 7.61500481e-04, 7.18623403e-04, 6.79529980e-04,
       6.43765274e-04, 6.10943886e-04, 5.80737083e-04, 5.52862706e-04,
       5.27077177e-04, 5.03169106e-04, 4.80954139e-04, 4.60270771e-04,
       0.00089761, 0.00088406, 0.00087099, 0.00085837, 0.00084617,
       0.00083438, 0.00082297, 0.00081193, 0.00080124, 0.00079087,
       0.00078081, 0.00077106, 0.00076158, 0.00075238, 0.00074344,
       0.00073474, 0.00072629, 0.00071805, 0.00071004, 0.00070223,
       0.00069462, 0.00068721, 0.00067998, 0.00067292, 0.00066604,
       0.00065931, 0.00065275, 0.00064634, 0.00064007, 0.00063394,
       0.00062795, 0.00062209, 0.00061636, 0.00061075, 0.00060525,
       0.00059987, 0.00059461, 0.00058944, 0.00058439, 0.00057943,
       0.00057457, 0.0005698 , 0.00056512, 0.00056053, 0.00055603,
       0.00055161, 0.00054727, 0.00054301, 0.00053883, 0.00053472,
       0.00053068, 0.00052671, 0.00052281, 0.00051898]
#----------------------------------------------------------------------

# %%
# repeatable workflow for figure-making
#--------------------------------------

# RUN 1
m_1, b_1 = np.polyfit(np.log(area[1:]), np.log(slope_1), 1)
slope_fit_1 = np.exp((m_1 * np.log(area[1:])) + b_1)

upper_bound_total_m_1 = m_1 + 0.05
lower_bound_total_m_1 = m_1 - 0.05

upper_bound_total_slope_fit_1 = np.exp((upper_bound_total_m_1 * np.log(area[1:])) + b_1)
lower_bound_total_slope_fit_1 = np.exp((lower_bound_total_m_1 * np.log(area[1:])) + b_1)
#---------------------------------------------------------------------------------

# RUN 2
m_2, b_2 = np.polyfit(np.log(area[1:]), np.log(slope_2), 1)
slope_fit_2 = np.exp((m_2 * np.log(area[1:])) + b_2)

upper_bound_total_m_2 = m_2 + 0.05
lower_bound_total_m_2 = m_2 - 0.05

upper_bound_total_slope_fit_2 = np.exp((upper_bound_total_m_2 * np.log(area[1:])) + b_2)
lower_bound_total_slope_fit_2 = np.exp((lower_bound_total_m_2 * np.log(area[1:])) + b_2)
#---------------------------------------------------------------------------------

# RUN 3
m_3, b_3 = np.polyfit(np.log(area[1:]), np.log(slope_3), 1)
slope_fit_3 = np.exp((m_3 * np.log(area[1:])) + b_3)

upper_bound_total_m_3 = m_3 + 0.05
lower_bound_total_m_3 = m_3 - 0.05

upper_bound_total_slope_fit_3 = np.exp((upper_bound_total_m_3 * np.log(area[1:])) + b_3)
lower_bound_total_slope_fit_3 = np.exp((lower_bound_total_m_3 * np.log(area[1:])) + b_3)
#---------------------------------------------------------------------------------

# RUN 4
m_4, b_4 = np.polyfit(np.log(area[1:]), np.log(slope_4), 1)
slope_fit_4 = np.exp((m_4 * np.log(area[1:])) + b_4)

upper_bound_total_m_4 = m_4 + 0.05
lower_bound_total_m_4 = m_4 - 0.05

upper_bound_total_slope_fit_4 = np.exp((upper_bound_total_m_4 * np.log(area[1:])) + b_4)
lower_bound_total_slope_fit_4 = np.exp((lower_bound_total_m_4 * np.log(area[1:])) + b_4)
#---------------------------------------------------------------------------------

# RUN 5
m_5, b_5 = np.polyfit(np.log(area[1:]), np.log(slope_5), 1)
slope_fit_5 = np.exp((m_5 * np.log(area[1:])) + b_5)

upper_bound_total_m_5 = m_5 + 0.05
lower_bound_total_m_5 = m_5 - 0.05

upper_bound_total_slope_fit_5 = np.exp((upper_bound_total_m_5 * np.log(area[1:])) + b_5)
lower_bound_total_slope_fit_5 = np.exp((lower_bound_total_m_5 * np.log(area[1:])) + b_5)
#---------------------------------------------------------------------------------

# RUN 6
m_6, b_6 = np.polyfit(np.log(area[1:]), np.log(slope_6), 1)
slope_fit_6 = np.exp((m_6 * np.log(area[1:])) + b_6)

upper_bound_total_m_6 = m_6 + 0.05
lower_bound_total_m_6 = m_6 - 0.05

upper_bound_total_slope_fit_6 = np.exp((upper_bound_total_m_6 * np.log(area[1:])) + b_6)
lower_bound_total_slope_fit_6 = np.exp((lower_bound_total_m_6 * np.log(area[1:])) + b_6)
#---------------------------------------------------------------------------------

# RUN 7
m_7, b_7 = np.polyfit(np.log(area[1:]), np.log(slope_7), 1)
slope_fit_7 = np.exp((m_7 * np.log(area[1:])) + b_7)

upper_bound_total_m_7 = m_7 + 0.05
lower_bound_total_m_7 = m_7 - 0.05

upper_bound_total_slope_fit_7 = np.exp((upper_bound_total_m_7 * np.log(area[1:])) + b_7)
lower_bound_total_slope_fit_7 = np.exp((lower_bound_total_m_7 * np.log(area[1:])) + b_7)
#---------------------------------------------------------------------------------

# RUN 8
m_8, b_8 = np.polyfit(np.log(area[1:]), np.log(slope_8), 1)
slope_fit_8 = np.exp((m_8 * np.log(area[1:])) + b_8)

upper_bound_total_m_8 = m_8 + 0.05
lower_bound_total_m_8 = m_8 - 0.05

upper_bound_total_slope_fit_8 = np.exp((upper_bound_total_m_8 * np.log(area[1:])) + b_8)
lower_bound_total_slope_fit_8 = np.exp((lower_bound_total_m_8 * np.log(area[1:])) + b_8)
#---------------------------------------------------------------------------------

# RUN 9
m_9, b_9 = np.polyfit(np.log(area[1:]), np.log(slope_9), 1)
slope_fit_9 = np.exp((m_9 * np.log(area[1:])) + b_9)

upper_bound_total_m_9 = m_9 + 0.05
lower_bound_total_m_9 = m_9 - 0.05

upper_bound_total_slope_fit_9 = np.exp((upper_bound_total_m_9 * np.log(area[1:])) + b_9)
lower_bound_total_slope_fit_9 = np.exp((lower_bound_total_m_9 * np.log(area[1:])) + b_9)

# %%
# now make pretty figure
plt.rcParams['figure.dpi'] = 300
fig, axs = plt.subplots(3, 3, figsize = (9, 6), sharex = True, sharey = True)
fig.text(0.04, 0.5, 'Slope', va='center', rotation='vertical', fontsize = 14)
fig.text(0.5, 0.04, 'Area $(m^2)$', ha='center', fontsize = 14)

fig.text(-0.01, 0.5, 'Increasing Abradability $\longrightarrow$', va='center', rotation='vertical', fontsize = 16)
fig.text(0.5, -0.01, 'Increasing Pluckability $\longrightarrow$', ha='center', fontsize = 16)

# ax.set_xlabel(r'$\rho/\rho_{ref}\;\rightarrow$', color='red')
# ax.set_ylabel(r'$\Delta \Theta / \omega \longrightarrow$')

# fig.suptitle('Slope-area relationships', fontsize = 16)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.2)

axs[0, 0].plot(area[1:], slope_1[:], color = 'midnightblue', linewidth = 2)
axs[0, 0].plot(area[1:], slope_fit_1, color = 'k',linestyle = ':')
axs[0, 0].plot(area[1:], upper_bound_total_slope_fit_1, color = 'k')
axs[0, 0].plot(area[1:], lower_bound_total_slope_fit_1, color = 'k')
axs[0, 0].fill_between(area[1:], upper_bound_total_slope_fit_1, lower_bound_total_slope_fit_1, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
axs[0, 0].set_yscale('log')
axs[0, 0].set_xscale('log')

axs[0, 1].plot(area[1:], slope_2[:], color = 'midnightblue', linewidth = 2)
axs[0, 1].plot(area[1:], slope_fit_2, color = 'k',linestyle = ':')
axs[0, 1].plot(area[1:], upper_bound_total_slope_fit_2, color = 'k')
axs[0, 1].plot(area[1:], lower_bound_total_slope_fit_2, color = 'k')
axs[0, 1].fill_between(area[1:], upper_bound_total_slope_fit_2, lower_bound_total_slope_fit_2, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
axs[0, 1].set_yscale('log')
axs[0, 1].set_xscale('log')

axs[0, 2].plot(area[1:], slope_3[:], color = 'midnightblue', linewidth = 2, label = 'Model prediction')
axs[0, 2].plot(area[1:], slope_fit_3, color = 'k',linestyle = ':', label = "Flint's Law")
axs[0, 2].plot(area[1:], upper_bound_total_slope_fit_3, color = 'k')
axs[0, 2].plot(area[1:], lower_bound_total_slope_fit_3, color = 'k')
axs[0, 2].fill_between(area[1:], upper_bound_total_slope_fit_3, lower_bound_total_slope_fit_3, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
axs[0, 2].set_yscale('log')
axs[0, 2].set_xscale('log')
axs[0, 2].legend(bbox_to_anchor=(1.1, 1.05))

axs[1, 0].plot(area[1:], slope_4[:], color = 'midnightblue', linewidth = 2)
axs[1, 0].plot(area[1:], slope_fit_4, color = 'k',linestyle = ':')
axs[1, 0].plot(area[1:], upper_bound_total_slope_fit_4, color = 'k')
axs[1, 0].plot(area[1:], lower_bound_total_slope_fit_4, color = 'k')
axs[1, 0].fill_between(area[1:], upper_bound_total_slope_fit_4, lower_bound_total_slope_fit_4, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
axs[1, 0].set_yscale('log')
axs[1, 0].set_xscale('log')

axs[1, 1].plot(area[1:], slope_5[:], color = 'midnightblue', linewidth = 2)
axs[1, 1].plot(area[1:], slope_fit_5, color = 'k',linestyle = ':')
axs[1, 1].plot(area[1:], upper_bound_total_slope_fit_5, color = 'k')
axs[1, 1].plot(area[1:], lower_bound_total_slope_fit_5, color = 'k')
axs[1, 1].fill_between(area[1:], upper_bound_total_slope_fit_5, lower_bound_total_slope_fit_5, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
axs[1, 1].set_yscale('log')
axs[1, 1].set_xscale('log')

axs[1, 2].plot(area[1:], slope_6[:], color = 'midnightblue', linewidth = 2)
axs[1, 2].plot(area[1:], slope_fit_6, color = 'k',linestyle = ':')
axs[1, 2].plot(area[1:], upper_bound_total_slope_fit_6, color = 'k')
axs[1, 2].plot(area[1:], lower_bound_total_slope_fit_6, color = 'k')
axs[1, 2].fill_between(area[1:], upper_bound_total_slope_fit_6, lower_bound_total_slope_fit_6, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
axs[1, 2].set_yscale('log')
axs[1, 2].set_xscale('log')

axs[2, 0].plot(area[1:], slope_7[:], color = 'midnightblue', linewidth = 2)
axs[2, 0].plot(area[1:], slope_fit_7, color = 'k',linestyle = ':')
axs[2, 0].plot(area[1:], upper_bound_total_slope_fit_7, color = 'k')
axs[2, 0].plot(area[1:], lower_bound_total_slope_fit_7, color = 'k')
axs[2, 0].fill_between(area[1:], upper_bound_total_slope_fit_7, lower_bound_total_slope_fit_7, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
axs[2, 0].set_yscale('log')
axs[2, 0].set_xscale('log')

axs[2, 1].plot(area[1:], slope_8[:], color = 'midnightblue', linewidth = 2)
axs[2, 1].plot(area[1:], slope_fit_8, color = 'k',linestyle = ':')
axs[2, 1].plot(area[1:], upper_bound_total_slope_fit_8, color = 'k')
axs[2, 1].plot(area[1:], lower_bound_total_slope_fit_8, color = 'k')
axs[2, 1].fill_between(area[1:], upper_bound_total_slope_fit_8, lower_bound_total_slope_fit_8, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
axs[2, 1].set_yscale('log')
axs[2, 1].set_xscale('log')

axs[2, 2].plot(area[1:], slope_9[:], color = 'midnightblue', linewidth = 2)
axs[2, 2].plot(area[1:], slope_fit_9, color = 'k',linestyle = ':')
axs[2, 2].plot(area[1:], upper_bound_total_slope_fit_9, color = 'k')
axs[2, 2].plot(area[1:], lower_bound_total_slope_fit_9, color = 'k')
axs[2, 2].fill_between(area[1:], upper_bound_total_slope_fit_9, lower_bound_total_slope_fit_9, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
axs[2, 2].set_yscale('log')
axs[2, 2].set_xscale('log')

plt.savefig('SA_parameter_space.png', bbox_inches='tight')
plt.show()

# %%
ax.plot(area[1:], slope_fit, color = 'k',linestyle = ':', label = "Flint's Law")
ax.plot(area[1:], upper_bound_total_slope_fit, color = 'k')
ax.plot(area[1:], lower_bound_total_slope_fit, color = 'k')
ax.fill_between(area[1:], upper_bound_total_slope_fit, lower_bound_total_slope_fit, color = 'silver', alpha = 0.2, label = '$\pm 0.05\ \\theta$')
# ax.fill_between(area[25:], upper_bound_down_slope_fit, lower_bound_down_slope_fit, color = 'k', alpha = 0.2)
ax.set_yscale('log')
ax.set_xscale('log')
# ax.vlines(area[24:25], 0.1, 0.00001, linestyle = '--', color = 'k', label = 'Bedrock contact')
# axs[0].set_title('Upstream', fontsize = 16)
ax.legend(loc = 'best', fontsize = 14)

# plt.savefig('AGU_SA_plot_single.png')
plt.show()
