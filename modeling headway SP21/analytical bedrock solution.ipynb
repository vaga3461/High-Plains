# %%
# trying an analytical soln to bedrock model
import numpy as np
import matplotlib.pyplot as plt

# %%
k = 0.01
c = 1
U = 0.002
x = np.arange(0, 100, 1)

a = c*x
b = k*x
c = -U

S = (-b + (np.sqrt((b**2) - 4*a*c)))/(2*a)
# Out:
# /Users/vanessa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.plot(x, S)
plt.show()
