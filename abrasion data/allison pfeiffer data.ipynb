# %%
# in this notebook, load Pfeiffer et al 2017 data for easy perusing

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('pfeiffer 2017 data.txt', delimiter = '\t', header = 1)
Be_data = pd.read_csv('pfeiffer 2017 erosion data.txt', delimiter = '\t', header = 1)

# %%
Be_data
# Out:
#     Pair Reach number                        Drainage  \
# 0    1.0     48,49,50                     Scott Creek
# 1    2.0          5,6                   Redwood Creek
# 2    3.0          102                          Selway
# 3    4.0          107                          Lochsa
# 4    5.0          187              Yellow Breeches Ck
# 5    6.0          186                      Sherman Ck
# 6    7.0          183     Spring Creek near Milesburg
# 7    8.0          189  Spring Creek near Houserville
# 8    9.0          313                         Bear Ck
# 9   10.0          315                    San Gregorio
# 10  11.0          311                N. Fk. Caspar Ck
# 11  12.0          232     South River at Harriston VA
# 12  13.0          235       Smith River near Woolwine
# 13  14.0          223                   Roanoke River
# 14  15.0          314                        Kings Ck
# 15  16.0           80                           Elder
# ...

# %%
# rename a bunch of columns
data.rename(columns={"Unnamed: 0": "ID", 
                     "Unnamed: 1": "Dataset Reference", 
                     "Unnamed: 5": "River/Reach Name",
                     "Unnamed: 6" : "Region",
                     "Unnamed: 7": "Slope",
                     "m": "D50",
                     "m.1": "Depth",
                     "m.2": "Width",
                     "km^2": "Drainage Area",
                     "D.dd": "Lat",
                     "D.dd.1": "Lon",
                     })
# Out:
#       ID             Dataset Reference           Unnamed: 2  Unnamed: 3  \
# 0      1           Abbe and Montgomery                    1        32.0
# 1      2           Abbe and Montgomery                    1        32.0
# 2      3           Abbe and Montgomery                    1        32.0
# 3      4           Abbe and Montgomery                    1        32.0
# 4      5             Lisle- Redwood Ck  20** and Madej 2009         NaN
# ..   ...                           ...                  ...         ...
# 336  346  Lisle personal communication                  NaN         NaN
# 337  347  Lisle personal communication                  NaN         NaN
# 338  348  Lisle personal communication                  NaN         NaN
# 339  349  Lisle personal communication                  NaN         NaN
# 340  350  Lisle personal communication                  NaN         NaN
#
#      Unnamed: 4                                   River/Reach Name  \
# ...

# %%
pd.set_option("max_rows", None)

# %%
data
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0             1                                Abbe and Montgomery
# 1             2                                Abbe and Montgomery
# 2             3                                Abbe and Montgomery
# 3             4                                Abbe and Montgomery
# 4             5                                  Lisle- Redwood Ck
# 5             6                                  Lisle- Redwood Ck
# 6             7                       Wood-Smith and Buffington AK
# 7             8                       Wood-Smith and Buffington AK
# 8             9                       Wood-Smith and Buffington AK
# 9            10                       Wood-Smith and Buffington AK
# 10           11                       Wood-Smith and Buffington AK
# 11           12                       Wood-Smith and Buffington AK
# 12           13                       Wood-Smith and Buffington AK
# ...
