# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('abby data csv.csv', header = 0)

# %%
data
# Out:
#    X-section          Area  Qb weighted average      Qb g         Qb lm  \
# 0     BCM-10  2.482480e+08         3.872650e-06  0.000004  3.777790e-06
# 1      BCM-9  2.855776e+08         2.163210e-04  0.000214  2.201550e-04
# 2      BCM-8  3.234408e+08         9.501520e-04  0.000938  1.053376e-03
# 3      BCM-7  3.837483e+08         3.540220e-03  0.003521  3.693727e-03
# 4      BCM-3  5.581488e+08         7.027050e-04  0.000702  7.433740e-04
# 5     BCM-11  6.043521e+08         4.773270e-04  0.000468  4.680360e-04
# 6      BCP-1  7.391560e+08         1.652791e-03  0.001637  1.774430e-03
# 7      BCP-2  7.558881e+08         2.791740e-04  0.000271  3.041490e-04
# 8      BCP-3  7.696008e+08         5.183800e-06  0.000005  5.224140e-06
# 9      BCP-4  7.857008e+08         1.327400e-04  0.000135  1.354150e-04
# 10     BCP-5  8.088492e+08         9.956080e-07  0.000001  9.560380e-07
# 11     BCP-6  8.253525e+08         8.813180e-05  0.000092  8.721050e-05
# ...

# %%
fig, axs = plt.subplots(1, 2, figsize = (16, 4), dpi = 300)

#axs[0].scatter(data['Area'][0:6], data['Qb total'][0:6], marker = 'x', s = 60)
axs[0].scatter(data['Area'][0:6], data['Qb g'][0:6], marker = 'x', s = 60, label = 'granite')
axs[0].scatter(data['Area'][0:6], data['Qb lm'][0:6], marker = 'x', s = 60, label = 'light metamorphic')
axs[0].scatter(data['Area'][0:6], data['Qb dm'][0:6], marker = 'x', s = 60, label = 'dark metamorphic')
axs[0].scatter(data['Area'][0:6], data['Qb v'][0:6], marker = 'x', s = 60, label = 'volcanic')
axs[0].set_xscale('log')
axs[0].legend()
axs[0].set_title('Mountains')
axs[0].set_xlabel('log(Area)')
axs[0].set_ylabel('Bedload transport rate (m^3/s)')

#axs[1].scatter(data['Area'][6:], data['Qb total'][6:], marker = 'x', s = 60)
axs[1].scatter(data['Area'][6:], data['Qb g'][6:], marker = 'x', s = 60, label = 'granite')
axs[1].scatter(data['Area'][6:], data['Qb lm'][6:], marker = 'x', s = 60, label = 'light metamorphic')
axs[1].scatter(data['Area'][6:], data['Qb dm'][6:], marker = 'x', s = 60, label = 'dark metamorphic')
axs[1].scatter(data['Area'][6:], data['Qb v'][6:], marker = 'x', s = 60, label = 'volcanic')
axs[1].scatter(data['Area'][6:], data['Qb ss'][6:], marker = 'x', s = 60, label = 'sandstone')
axs[1].set_xscale('log')
axs[1].legend()
axs[1].set_title('Plains')
axs[1].set_xlabel('log(Area)')
# Out:
# Text(0.5, 0, 'log(Area)')
